# %%
## step 1
original_number='123'

## create infinite while loop

while True:

## step 2 and step 6
  guess_number= input('')
  output=[]

## step 3 and step 4 (use continue statement)
  # print(len(original_number))
  # print(len(guess_number))

  if len(original_number)!= len(guess_number):
    print('enter valid input')
  s={i for  i in guess_number}
  if len(s)!=len(guess_number):
    print('duplicate number')
    continue

## step 5 (use break statement for winning condition)
  if original_number==guess_number:
    print('fermi' * len(original_number))
    break

## step 7
  for i,j in enumerate(original_number):
    for k,l in enumerate(guess_number):
      if j==l and i==k:
        # print('Fermi', end=' ')
        output.append('Fermi')
      elif j==l:
        # print('Pico')
        output.append('Pico')
  # print(output)

## step 8
  output_string=''
  for n in output:
    output_string+=n+' '
  print(output_string)

## step 9
  if len(output)==0:
    print('Bagel')
  # else:
    # print (output)
    # for i in output:
    #   print(i,end=' ')
